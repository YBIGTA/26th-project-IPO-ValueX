# %%
import pandas as pd

year = 2015

# %%
df = pd.read_csv(f'./output/cat_{year}.csv')
df.head()
# Out:
#                                                 link     성장_긍정     성장_부정  \
# 0  https://n.news.naver.com/mnews/article/277/000...  0.311563  0.297313
# 1  https://n.news.naver.com/mnews/article/008/000...  0.262022  0.235280
# 2  https://n.news.naver.com/mnews/article/057/000...  0.111002  0.184532
# 3  https://n.news.naver.com/mnews/article/011/000...  0.242924  0.205275
# 4  https://n.news.naver.com/mnews/article/011/000...  0.236430  0.249795
#
#       민감_긍정     민감_부정     방어_긍정     방어_부정     금융_긍정     금융_부정
# 0  0.443202  0.358960  0.400885  0.325710  0.399166  0.314839
# 1  0.247219  0.160215  0.302060  0.204197  0.166990  0.113417
# 2  0.058031  0.204129  0.100046  0.196763  0.029690  0.172604
# 3  0.168708  0.165718  0.219933  0.113296  0.204156  0.175891
# 4  0.208943  0.243843  0.237467  0.170352  0.276045  0.265302

# %%
index = 22

print(df['link'].tolist()[index])
print(df.iloc[index])
# Out:
# https://n.news.naver.com/mnews/article/014/0003334585
# link     https://n.news.naver.com/mnews/article/014/000...
# 성장_긍정                                             0.198647
# 성장_부정                                             0.346895
# 민감_긍정                                             0.298244
# 민감_부정                                             0.339112
# 방어_긍정                                             0.289749
# 방어_부정                                             0.321758
# 금융_긍정                                             0.354238
# 금융_부정                                             0.421392
# Name: 22, dtype: object
