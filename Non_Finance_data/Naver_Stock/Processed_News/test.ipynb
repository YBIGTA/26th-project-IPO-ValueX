# %% [markdown]
# 데이터 컬럼 확인을 위해 만들어진 코드입니다.

# %%
import pandas as pd
df = pd.read_csv('Naver_Stock_preprocessed_final_2021.csv')
df.head(3)
# Out:
#                        Title      Date  Press  \
# 0     현대제철 수익성 개선…"밸류에이션 부각"  20210101  헤럴드경제
# 1  4분기 부진한 한국가스공사, "올해는 정상화"  20210101  헤럴드경제
# 2    개미가 이끈 코스피, 역대 첫 GDP 넘어  20210101   문화일보
#
#                                                 Link  \
# 0  https://n.news.naver.com/mnews/article/016/000...
# 1  https://n.news.naver.com/mnews/article/016/000...
# 2  https://n.news.naver.com/mnews/article/021/000...
#
#                                                 Body  \
# 0  [헤럴드경제=이세진 기자] 올 상반기 철강재 가격 강세가 지속되면서 현대제철 ASP...
# 1  [헤럴드경제=이세진 기자] 지난해 4분기 예상보다 부진했던 실적을 딛고 올해 한국가...
# 2  명목 GDP 대비 시가총액 104%로 역대 최대\n\n지난해 코스피 상장기업의 시가...
#
#                                Emotion  \
# 0  Good:15 Warm:0 Sad:0 Angry:1 Want:0
# 1   Good:3 Warm:1 Sad:0 Angry:2 Want:0
# 2   Good:6 Warm:0 Sad:0 Angry:1 Want:0
#
#                                         Comment_body  \
# 0                                                NaN
# 1  정부정책을 무시하는 가스공사는 작년에도 성과급을 지급한거로 안다.비정규직의 직고용은...
# ...
